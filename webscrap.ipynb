# %% [markdown]
# ### Import

# %%
import requests
from bs4 import BeautifulSoup
import time
import csv
import pandas as pd

# %%
# !pip install langdetect
# Out:
# Collecting langdetect
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 11.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from langdetect) (1.17.0)
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993222 sha256=ef3df2c26dd7a6d0df66e933e446ea454439be5528db227e46fd7763366b2ca4
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
# Successfully built langdetect
# Installing collected packages: langdetect
# Successfully installed langdetect-1.0.9

# %% [markdown]
# ### URL

# %%
# base URL for the Trustpilot page

base_url = "https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency"
#base_url = "https://www.trustpilot.com/review/www.hotelsone.com"
#base_url = "https://www.trustpilot.com/review/www.galahotels.com"


# headers to mimic a browser
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

output_file = "./scrapped_reviews/trustpilot_reviews_1.csv"
#output_file = "./scrapped_reviews/trustpilot_reviews_2.csv"
#output_file = "./scrapped_reviews/trustpilot_reviews_3.csv"

# %% [markdown]
# ### Functions

# %%
# function to scrape a single page
def scrape_page(url, page_num):
    print(f"Scraping page {page_num}: {url}")
    response = requests.get(url, headers=headers)

    if response.status_code != 200:
        print(f"Failed to load page {page_num}. Status code: {response.status_code}")
        return []

    soup = BeautifulSoup(response.content, "html.parser")

    # find all review containers
    reviews = soup.find_all("article", class_="paper_paper__1PY90")  # Update class name if structure changes

    # store extracted reviews
    scraped_reviews = []

    for review in reviews:
        # Extract review title
        title_tag = review.find("h2", attrs={"data-service-review-title-typography": "true"})
        title = title_tag.text.strip() if title_tag else "No title"

        # Extract review body
        body_tag = review.find("p", attrs={"data-service-review-text-typography": "true"})
        body = body_tag.text.strip() if body_tag else "No body text"

        # Extract review date
        date_tag = review.find("p", attrs={"data-service-review-date-of-experience-typography": "true"})
        date = date_tag.text.strip() if date_tag else "No date"

        # Append the review data
        scraped_reviews.append({
            "title": title,
            "body": body,
            "date": date
        })

    return scraped_reviews



# Main function to scrape multiple pages
def scrape_multiple_pages(base_url, max_pages):
    all_reviews = []

    with open(output_file, mode="w", newline="", encoding="utf-8") as file:
        writer = csv.DictWriter(file, fieldnames=["title", "body", "date"])
        writer.writeheader()

        for page_num in range(1, max_pages + 1):
            page_url = f"{base_url}?page={page_num}"
            reviews = scrape_page(page_url, page_num)

            all_reviews.extend(reviews)

            # write to CSV after every page
            writer.writerows(reviews)

            if not reviews:
                print(f"No more reviews found. Stopping at page {page_num}.")
                break

            time.sleep(2)

    print(f"Scraping complete. {len(all_reviews)} reviews saved to {output_file}.")
    return all_reviews

# Scrape up to 250 pages
max_pages = 250
scraped_reviews = scrape_multiple_pages(base_url, max_pages)
# Out:
# Scraping page 1: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=1
# Scraping page 2: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=2
# Scraping page 3: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=3
# Scraping page 4: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=4
# Scraping page 5: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=5
# Scraping page 6: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=6
# Scraping page 7: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=7
# Scraping page 8: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=8
# Scraping page 9: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=9
# Scraping page 10: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=10
# Scraping page 11: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=11
# Scraping page 12: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=12
# Scraping page 13: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=13
# Scraping page 14: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=14
# Scraping page 15: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=15
# Scraping page 16: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=16
# Scraping page 17: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=17
# Scraping page 18: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=18
# Scraping page 19: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=19
# Scraping page 20: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=20
# Scraping page 21: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=21
# Scraping page 22: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=22
# Scraping page 23: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=23
# Scraping page 24: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=24
# Scraping page 25: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=25
# Scraping page 26: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=26
# Scraping page 27: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=27
# Scraping page 28: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=28
# Scraping page 29: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=29
# Scraping page 30: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=30
# Scraping page 31: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=31
# Scraping page 32: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=32
# Scraping page 33: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=33
# Scraping page 34: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=34
# Scraping page 35: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=35
# Scraping page 36: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=36
# Scraping page 37: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=37
# Scraping page 38: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=38
# Scraping page 39: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=39
# Scraping page 40: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=40
# Scraping page 41: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=41
# Scraping page 42: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=42
# Scraping page 43: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=43
# Scraping page 44: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=44
# Scraping page 45: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=45
# Scraping page 46: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=46
# Scraping page 47: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=47
# Scraping page 48: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=48
# Scraping page 49: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=49
# Scraping page 50: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=50
# Scraping page 51: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=51
# Scraping page 52: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=52
# Scraping page 53: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=53
# Scraping page 54: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=54
# Scraping page 55: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=55
# Scraping page 56: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=56
# Scraping page 57: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=57
# Scraping page 58: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=58
# Scraping page 59: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=59
# Scraping page 60: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=60
# Scraping page 61: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=61
# Scraping page 62: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=62
# Scraping page 63: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=63
# Scraping page 64: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=64
# Scraping page 65: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=65
# Scraping page 66: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=66
# Scraping page 67: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=67
# Scraping page 68: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=68
# Scraping page 69: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=69
# Scraping page 70: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=70
# Scraping page 71: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=71
# Scraping page 72: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=72
# Scraping page 73: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=73
# Scraping page 74: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=74
# Scraping page 75: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=75
# Scraping page 76: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=76
# Scraping page 77: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=77
# Scraping page 78: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=78
# Scraping page 79: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=79
# Scraping page 80: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=80
# Scraping page 81: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=81
# Scraping page 82: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=82
# Scraping page 83: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=83
# Scraping page 84: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=84
# Scraping page 85: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=85
# Scraping page 86: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=86
# Scraping page 87: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=87
# Scraping page 88: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=88
# Scraping page 89: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=89
# Scraping page 90: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=90
# Scraping page 91: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=91
# Scraping page 92: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=92
# Scraping page 93: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=93
# Scraping page 94: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=94
# Scraping page 95: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=95
# Scraping page 96: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=96
# Scraping page 97: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=97
# Scraping page 98: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=98
# Scraping page 99: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=99
# Scraping page 100: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=100
# Scraping page 101: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=101
# Scraping page 102: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=102
# Scraping page 103: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=103
# Scraping page 104: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=104
# Scraping page 105: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=105
# Scraping page 106: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=106
# Scraping page 107: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=107
# Scraping page 108: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=108
# Scraping page 109: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=109
# Scraping page 110: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=110
# Scraping page 111: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=111
# Scraping page 112: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=112
# Scraping page 113: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=113
# Scraping page 114: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=114
# Scraping page 115: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=115
# Scraping page 116: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=116
# Scraping page 117: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=117
# Scraping page 118: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=118
# Scraping page 119: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=119
# Scraping page 120: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=120
# Scraping page 121: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=121
# Scraping page 122: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=122
# Scraping page 123: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=123
# Scraping page 124: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=124
# Scraping page 125: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=125
# Scraping page 126: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=126
# Scraping page 127: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=127
# Scraping page 128: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=128
# Scraping page 129: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=129
# Scraping page 130: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=130
# Scraping page 131: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=131
# Scraping page 132: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=132
# Scraping page 133: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=133
# Scraping page 134: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=134
# Scraping page 135: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=135
# Scraping page 136: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=136
# Scraping page 137: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=137
# Scraping page 138: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=138
# Scraping page 139: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=139
# Scraping page 140: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=140
# Scraping page 141: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=141
# Scraping page 142: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=142
# Scraping page 143: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=143
# Scraping page 144: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=144
# Scraping page 145: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=145
# Scraping page 146: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=146
# Scraping page 147: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=147
# Scraping page 148: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=148
# Scraping page 149: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=149
# Scraping page 150: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=150
# Scraping page 151: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=151
# Scraping page 152: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=152
# Scraping page 153: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=153
# Scraping page 154: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=154
# Scraping page 155: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=155
# Scraping page 156: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=156
# Scraping page 157: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=157
# Scraping page 158: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=158
# Scraping page 159: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=159
# Scraping page 160: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=160
# Scraping page 161: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=161
# Scraping page 162: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=162
# Scraping page 163: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=163
# Scraping page 164: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=164
# Scraping page 165: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=165
# Scraping page 166: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=166
# Scraping page 167: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=167
# Scraping page 168: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=168
# Scraping page 169: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=169
# Scraping page 170: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=170
# Scraping page 171: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=171
# Scraping page 172: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=172
# Scraping page 173: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=173
# Scraping page 174: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=174
# Scraping page 175: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=175
# Scraping page 176: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=176
# Scraping page 177: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=177
# Scraping page 178: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=178
# Scraping page 179: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=179
# Scraping page 180: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=180
# Scraping page 181: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=181
# Scraping page 182: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=182
# Scraping page 183: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=183
# Scraping page 184: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=184
# Scraping page 185: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=185
# Scraping page 186: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=186
# Scraping page 187: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=187
# Scraping page 188: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=188
# Scraping page 189: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=189
# Scraping page 190: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=190
# Scraping page 191: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=191
# Scraping page 192: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=192
# Scraping page 193: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=193
# Scraping page 194: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=194
# Scraping page 195: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=195
# Scraping page 196: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=196
# Scraping page 197: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=197
# Scraping page 198: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=198
# Scraping page 199: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=199
# Scraping page 200: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=200
# Scraping page 201: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=201
# Scraping page 202: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=202
# Scraping page 203: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=203
# Scraping page 204: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=204
# Scraping page 205: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=205
# Scraping page 206: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=206
# Scraping page 207: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=207
# Scraping page 208: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=208
# Scraping page 209: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=209
# Scraping page 210: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=210
# Scraping page 211: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=211
# Scraping page 212: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=212
# Scraping page 213: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=213
# Scraping page 214: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=214
# Scraping page 215: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=215
# Scraping page 216: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=216
# Scraping page 217: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=217
# Scraping page 218: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=218
# Scraping page 219: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=219
# Scraping page 220: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=220
# Scraping page 221: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=221
# Scraping page 222: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=222
# Scraping page 223: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=223
# Scraping page 224: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=224
# Scraping page 225: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=225
# Scraping page 226: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=226
# Scraping page 227: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=227
# Scraping page 228: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=228
# Scraping page 229: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=229
# Scraping page 230: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=230
# Scraping page 231: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=231
# Scraping page 232: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=232
# Scraping page 233: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=233
# Scraping page 234: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=234
# Scraping page 235: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=235
# Scraping page 236: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=236
# Scraping page 237: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=237
# Scraping page 238: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=238
# Scraping page 239: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=239
# Scraping page 240: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=240
# Scraping page 241: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=241
# Scraping page 242: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=242
# Scraping page 243: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=243
# Scraping page 244: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=244
# Scraping page 245: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=245
# Scraping page 246: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=246
# Scraping page 247: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=247
# Scraping page 248: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=248
# Scraping page 249: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=249
# Scraping page 250: https://www.trustpilot.com/review/www.hrs.de?languages=all&sort=recency?page=250
# Scraping complete. 5000 reviews saved to ./scrapped_reviews/trustpilot_reviews_1.csv.

# %% [markdown]
# ### RSE multilanguage

# %%
import csv
from langdetect import detect

# Define RSE related keywords for multiple languages
keywords = {
    "en": {
        "positive": ["eco-friendly", "sustainable", "green", "energy", "fair", "wages", "renewable", "recycling", "ethical", "carbon", "neutral", "clean", "organic", "friendly", "low", "emissions", "initiatives", "diversity", "community", "local", "efficiency", "responsible"],
        "negative": ["greenwashing", "unethical", "unsustainable", "wasteful", "exploitation", "pollution", "bad", "conditions", "high", "emissions", "deforestation", "toxic", "violations", "child", "labor", "lack", "transparency", "damage"]
    },
    "fr": {
        "positive": ["éco", "responsable", "durable", "énergie", "verte", "salaires", "équitables", "renouvelable", "recyclage", "éthique", "carbone", "neutre", "propre", "bio", "respectueux", "environnement", "basses", "émissions", "initiatives", "diversité", "communauté", "locale", "efficacité", "tourisme"],
        "negative": ["écoblanchiment", "non éthique", "durable", "gaspillage", "exploitation", "pollution", "mauvaises", "conditions", "élevées", "émissions", "déforestation", "toxique", "violations", "droits", "enfants", "manque", "transparence", "dégradations"]
    },
    "es": {
        "positive": ["ecológico", "sostenible", "energía", "verde", "salarios", "justos", "renovable", "reciclaje", "ético", "carbono", "neutral", "limpia", "orgánico", "respetuoso", "medio", "ambiente", "bajas", "emisiones", "iniciativas", "diversidad", "comunidad", "local", "eficiencia", "turismo"],
        "negative": ["lavado", "verde", "no ético", "sostenible", "desperdicio", "explotación", "contaminación", "malas", "condiciones", "altas", "emisiones", "deforestación", "tóxico", "violaciones", "derechos", "infantil", "falta", "transparencia", "daños"]
    },
    "de": {
        "positive": ["umwelt", "freundlich", "nachhaltig", "grün", "energie", "faire", "löhne", "erneuerbar", "recycling", "ethisch", "klima", "neutral", "sauber", "bio", "freundlich", "niedrige", "emissionen", "initiativen", "vielfalt", "gemeinschaft", "lokal", "effizienz", "tourismus"],
        "negative": ["greenwashing", "unethisch",  "nachhaltig", "verschwendung", "ausbeutung", "verschmutzung", "schlechte", "bedingungen", "hohe", "emissionen", "abholzung", "giftig", "menschen", "rechte", "kinderarbeit", "mangel", "transparenz", "schäden"]
    },
    "pt": {
        "positive": ["ecológico", "sustentável", "energia", "verde", "salários", "justos", "renovável", "reciclagem", "ético", "carbono", "neutro", "limpa", "orgânico", "amigável", "meio", "ambiente", "baixas", "emissões", "iniciativas", "diversidade", "comunidade", "local", "eficiência", "turismo"],
        "negative": ["greenwashing", "antiético", "sustentável", "desperdício", "exploração", "poluição", "más", "condições", "altas", "emissões", "desmatamento", "tóxico", "violaciones", "direitos", "infantil", "falta", "transparência", "danos"]
    },
    "it": {
        "positive": ["ecologico", "sostenibile", "energia", "verde", "salari", "equi", "rinnovabile", "riciclaggio", "etico", "carbonio", "neutro", "pulita", "bio", "rispettoso", "ambiente", "basse", "emissioni", "iniziative", "diversità", "comunità", "locale", "efficienza", "turismo"],
        "negative": ["greenwashing", "non etico", "sostenibile", "spreco", "sfruttamento", "inquinamento", "cattive", "condizioni", "alte", "emissioni", "deforestazione", "tossico", "violazioni", "diritti", "minori", "mancanza", "trasparenza", "danni"]
    }
}


input_file = "./scrapped_reviews/trustpilot_reviews_1.csv"  # Input CSV file with scraped reviews
output_file = "./test_classification/trustpilot_rse_classified_reviews_multilingual_1.csv"  # Output CSV file with classifications

# Function to classify reviews based on RSE keywords
def classify_review(text, language):
    text_lower = text.lower()  # Convert to lowercase for case insensitive matching
    lang_keywords = keywords.get(language, None)  # Get keywords for the detected language

    if lang_keywords:
        if any(keyword in text_lower for keyword in lang_keywords["positive"]):
            return "Positive"

        if any(keyword in text_lower for keyword in lang_keywords["negative"]):
            return "Negative"

    return "Neutral"

# Read reviews from the input file and classify them
classified_reviews = []

with open(input_file, mode="r", encoding="utf-8") as file:
    reader = csv.DictReader(file)
    for row in reader:
        review_body = row["body"]  # The review text column

        # Detect the language of the review
        try:
            language = detect(review_body)
        except:
            language = "unknown"

        # Classify the review based on the detected language
        classification = classify_review(review_body, language)
        row["language"] = language  # Add detected language to the row
        row["classification"] = classification  # Add classification to the row
        classified_reviews.append(row)

# Write the classified reviews to a new CSV file
with open(output_file, mode="w", newline="", encoding="utf-8") as file:
    fieldnames = ["title", "body", "date", "language", "classification"]  # Include language and classification columns
    writer = csv.DictWriter(file, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(classified_reviews)

print(f"Multilingual RSE classification complete. Results saved to {output_file}.")
# Out:
# Multilingual RSE classification complete. Results saved to ./test_classification/trustpilot_rse_classified_reviews_multilingual_1.csv.

# %%
df = pd.read_csv("./test_classification/trustpilot_rse_classified_reviews_multilingual_1.csv")
df1 = df[df["classification"]=="Negative"]
df1["body"]
# Out:
# 5       I found this site using ChatGPT (I've tried to...
# 14      Hotel didn't guarantee my reservation.  They d...
# 25      I found this site using ChatGPT (I've tried to...
# 34      Hotel didn't guarantee my reservation.  They d...
# 45      I found this site using ChatGPT (I've tried to...
#                               ...
# 4954    Hotel didn't guarantee my reservation.  They d...
# 4965    I found this site using ChatGPT (I've tried to...
# 4974    Hotel didn't guarantee my reservation.  They d...
# 4985    I found this site using ChatGPT (I've tried to...
# 4994    Hotel didn't guarantee my reservation.  They d...
# Name: body, Length: 500, dtype: object

# %%
df = pd.read_csv("./test_classification/trustpilot_rse_classified_reviews_multilingual_1.csv")
df1 = df[df["classification"]=="Positive"]
df1["body"]
# Out:
# 3       This was a great hotel. very comfortable and p...
# 4       Friendly staff, good location, clean and spaci...
# 12      Initially changed to HRS to support a local bu...
# 16      This site has often special offers for high qu...
# 23      This was a great hotel. very comfortable and p...
#                               ...
# 4976    This site has often special offers for high qu...
# 4983    This was a great hotel. very comfortable and p...
# 4984    Friendly staff, good location, clean and spaci...
# 4992    Initially changed to HRS to support a local bu...
# 4996    This site has often special offers for high qu...
# Name: body, Length: 1000, dtype: object
